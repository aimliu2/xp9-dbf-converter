# %% [markdown]
# # Preview DBF Database
# use this notebook to preview DBF Database

# %%
import dbf

# %%
# dbf_filename = "Data/TRANSACT.DBF"
dbf_filename = "Data/DBTH.DBF"
encoding = "utf8"
# encoding = "cp874" #thai
# cannot decode customer.dbf
table = dbf.Table(dbf_filename, codepage=encoding, on_disk=True)
field_names = table.field_names
table.open()
# Do something here
print('total data {}'.format(len(table)))
# sample = table[15915]
# row = {field_name: sample[field_name] for field_name in field_names}
# print(sample)


for record in table[-20:]:
    row = {field_name: record[field_name] for field_name in field_names}
    print(row)  # You can use row.field_name to get each field's data also

table.close()

# %%
dbf_filename = "Data/TRANSACT.DBF"
# dbf_filename = "Data/DBTH.DBF"
# encoding = "utf8"
encoding = "cp874" #thai
# cannot decode customer.dbf
table = dbf.Table(dbf_filename, codepage=encoding, on_disk=True)
field_names = table.field_names
table.open()
# Do something here

# single lookup
# print('total data {}'.format(len(table)))
# sample = table[0]
# row = {field_name: sample[field_name] for field_name in field_names}
# # print(sample)
# print(table)
# print(row)


for record in table:
    row = {field_name: record[field_name] for field_name in field_names}
    print(row)  # You can use row.field_name to get each field's data also

table.close()
